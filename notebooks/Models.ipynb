# %% [markdown]
# Preprocessing

# %%
from src.preprocess import load_clean_data, train_test_split_data, build_preprocessing_pipeline
from src.model_tree import build_decision_tree_model, evaluate_decision_tree

X, y = load_clean_data()
X_train, X_test, y_train, y_test = train_test_split_data(X, y)

preprocessor = build_preprocessing_pipeline(X)
tree_model = build_decision_tree_model(preprocessor, max_depth=5)

tree_model.fit(X_train, y_train)
evaluate_decision_tree(tree_model, X_test, y_test)
